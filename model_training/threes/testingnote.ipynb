# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from model_training.assists.features import build_all_assists_features, AST_FEATURES
#       3 df = pd.read_csv("your_path_here.csv")
#       4 feat_df = build_all_assists_features(df)
#
# ModuleNotFoundError: No module named 'model_training'
